# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("Iris.csv")
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.shape
# Out:
# (150, 6)

# %%
df.size
# Out:
# 900

# %%
def feature(df):
    numerics=df.select_dtypes(include=['number']).columns.tolist()
    nominal=df.select_dtypes(exclude=['number']).columns.tolist()
    return (numerics,nominal)
feature(df)
# Out:
# (['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm'],
#  ['Species'])

# %%
df.hist()
fig=plt.gcf()
fig.set_size_inches(15,8)

# %%
sns.boxplot(x='Species',y='SepalLengthCm',hue='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalLengthCm'>

# %%
sns.boxplot(x='Species',y='SepalWidthCm',hue='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='SepalWidthCm'>

# %%
sns.boxplot(x='Species',y='PetalLengthCm',hue='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalLengthCm'>

# %%
sns.boxplot(x='Species',y='PetalWidthCm',hue='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='PetalWidthCm'>

# %%
df.groupby('SepalLengthCm').min()
# Out:
#                 Id  SepalWidthCm  PetalLengthCm  PetalWidthCm          Species
# SepalLengthCm
# 4.3             14           3.0            1.1           0.1      Iris-setosa
# 4.4              9           2.9            1.3           0.2      Iris-setosa
# 4.5             42           2.3            1.3           0.3      Iris-setosa
# 4.6              4           3.1            1.0           0.2      Iris-setosa
# 4.7              3           3.2            1.3           0.2      Iris-setosa
# 4.8             12           3.0            1.4           0.1      Iris-setosa
# 4.9              2           2.4            1.4           0.1      Iris-setosa
# 5.0              5           2.0            1.2           0.2      Iris-setosa
# 5.1              1           2.5            1.4           0.2      Iris-setosa
# 5.2             28           2.7            1.4           0.1      Iris-setosa
# 5.3             49           3.7            1.5           0.2      Iris-setosa
# ...

# %%
df.groupby('Species').max()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa       50            5.8           4.4            1.9           0.6
# Iris-versicolor  100            7.0           3.4            5.1           1.8
# Iris-virginica   150            7.9           3.8            6.9           2.5

# %%
df.groupby('Species').min()
# Out:
#                   Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa        1            4.3           2.3            1.0           0.1
# Iris-versicolor   51            4.9           2.0            3.0           1.0
# Iris-virginica   101            4.9           2.2            4.5           1.4

# %%
df.groupby('Species').mean()
# Out:
#                     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# Species
# Iris-setosa       25.5          5.006         3.418          1.464
# Iris-versicolor   75.5          5.936         2.770          4.260
# Iris-virginica   125.5          6.588         2.974          5.552
#
#                  PetalWidthCm
# Species
# Iris-setosa             0.244
# Iris-versicolor         1.326
# Iris-virginica          2.026

# %%
sns.countplot(x='Species',hue='Species',data=df)
# Out:
# <Axes: xlabel='Species', ylabel='count'>

# %%
Q1=df['SepalLengthCm'].quantile(0.25)
Q3=df['SepalLengthCm'].quantile(0.75)
IQR=1.5*(Q3-Q1)
lb=Q1-IQR
ub=Q3+IQR
print(lb,ub)
filtered_df=df[(df['SepalLengthCm']>=lb) & (df['SepalLengthCm']<=ub)]
sns.histplot(x='SepalLengthCm',hue='Species',data=filtered_df,kde=True)
# Out:
# 3.1499999999999986 8.350000000000001
# <Axes: xlabel='SepalLengthCm', ylabel='Count'>

# %%
Q1=df['SepalWidthCm'].quantile(0.25)
Q3=df['SepalWidthCm'].quantile(0.75)
IQR=1.5*(Q3-Q1)
lb=Q1-IQR
ub=Q3+IQR
print(lb,ub)
filtered_df=df[(df['SepalWidthCm']>=lb) & (df['SepalWidthCm']<=ub)]
sns.histplot(x='SepalWidthCm',hue='Species',data=filtered_df,kde=True)
# Out:
# 2.05 4.05
# <Axes: xlabel='SepalWidthCm', ylabel='Count'>

# %%
Q1=df['PetalWidthCm'].quantile(0.25)
Q3=df['PetalWidthCm'].quantile(0.75)
IQR=1.5*(Q3-Q1)
lb=Q1-IQR
ub=Q3+IQR
print(lb,ub)
filtered_df=df[(df['PetalWidthCm']>=lb) & (df['PetalWidthCm']<=ub)]
sns.histplot(x='PetalWidthCm',hue='Species',data=filtered_df,kde=True)
# Out:
# -1.95 4.05
# <Axes: xlabel='PetalWidthCm', ylabel='Count'>

# %%
Q1=df['PetalLengthCm'].quantile(0.25)
Q3=df['PetalLengthCm'].quantile(0.75)
IQR=1.5*(Q3-Q1)
lb=Q1-IQR
ub=Q3+IQR
print(lb,ub)
filtered_df=df[(df['PetalLengthCm']>=lb) & (df['PetalLengthCm']<=ub)]
sns.histplot(x='PetalLengthCm',hue='Species',data=filtered_df,kde=True)
# Out:
# -3.649999999999999 10.349999999999998
# <Axes: xlabel='PetalLengthCm', ylabel='Count'>

# %%
new_df=df.copy()
new_df=new_df.drop('Id',axis=1)
new_df.boxplot(figsize=(15,8))
# Out:
# <Axes: >

# %%
Q1=new_df['SepalWidthCm'].quantile(0.25)
Q3=new_df['SepalWidthCm'].quantile(0.75)
IQR=1.5*(Q3-Q1)
lb=Q1-IQR
ub=Q3+IQR
print(lb)
print(ub)
new_df=new_df[(new_df['SepalWidthCm']>=lb) & (new_df['SepalWidthCm']<=ub)]
# Out:
# 2.05
# 4.05

# %%
new_df.boxplot(figsize=(15,8))
# Out:
# <Axes: >
